# %% [markdown]
# # GNN Explain by GRAD
#
# This notebook is designed to visualize the results of the GNN Explainer.
# - networkx: https://www.cxybb.com/article/DD18203614685/99285646

# %%
import os
import re
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
plt.rcParams['font.family']='SimHei'
plt.rcParams['axes.unicode_minus']=False
os.getcwd()
graph_type = 'doc_word_sen' #'context_centernode'

# %%
# 获取labelmap
label_map = {0:'非投诉会话',1:'客户感受差',2:'投诉',3:'3 推诿',4:'未解决问题',5:'四到类',6:'6 人身伤害',10:'10 重复提问',99:'词',-1:'未知标签'}

# %%
nodeid2txt = {}
path = r'E:\0_code\gnn-model-explainer-master_hql\data'
nodeid2txt_path = os.path.join(path,graph_type,'nodeid2txt.txt')
with open(nodeid2txt_path,'r',encoding='utf-8') as fr:
    lines = fr.readlines()
    for line in lines[1:]:
        nodeidx,txt = line.strip('\n').split('\t')
        nodeid2txt[nodeidx]=txt

# %%
# 获取nodeid2label
feature_labels_path = os.path.join(path,graph_type,'feature_label.csv')
df_feature_labels = pd.read_csv(feature_labels_path,sep='\t')
nodeid = df_feature_labels['nodeid']
labels = df_feature_labels['label']
nodeid2label = dict(zip(nodeid,labels))
nodeid2label
# Out:
# {0: 99,
#  1: 99,
#  2: 99,
#  3: 99,
#  4: 99,
#  5: 99,
#  6: 99,
#  7: 99,
#  8: 99,
#  9: 99,
#  10: 99,
#  11: 99,
#  12: 99,
#  13: 99,
#  14: 99,
#  15: 99,
#  16: 99,
#  17: 99,
#  18: 99,
#  19: 99,
#  20: 99,
#  21: 99,
#  22: 99,
#  23: 99,
#  24: 99,
#  25: 99,
#  26: 99,
#  27: 99,
#  28: 99,
#  29: 99,
#  30: 99,
#  31: 99,
#  32: 99,
#  33: 99,
#  34: 99,
#  35: 99,
#  36: 99,
#  37: 99,
#  38: 99,
#  39: 99,
#  40: 99,
#  41: 99,
#  42: 99,
#  43: 99,
#  44: 99,
#  45: 99,
#  46: 99,
#  47: 99,
#  48: 99,
#  49: 99,
#  50: 99,
#  51: 99,
#  52: 99,
#  53: 99,
#  54: 99,
#  55: 99,
#  56: 99,
#  57: 99,
#  58: 99,
#  59: 99,
#  60: 99,
#  61: 99,
#  62: 99,
#  63: 99,
#  64: 99,
#  65: 99,
#  66: 99,
#  67: 99,
#  68: 99,
#  69: 99,
#  70: 99,
#  71: 99,
#  72: 99,
#  73: 99,
#  74: 99,
#  75: 99,
#  76: 99,
#  77: 99,
#  78: 99,
#  79: 99,
#  80: 99,
#  81: 99,
#  82: 99,
#  83: 99,
#  84: 99,
#  85: 99,
#  86: 99,
#  87: 99,
#  88: 99,
#  89: 99,
#  90: 99,
#  91: 99,
#  92: 99,
#  93: 99,
#  94: 99,
#  95: 99,
#  96: 99,
#  97: 99,
#  98: 99,
#  99: 99,
#  100: 99,
#  101: 99,
#  102: 99,
#  103: 99,
#  104: 99,
#  105: 99,
#  106: 99,
#  107: 99,
#  108: 99,
#  109: 99,
#  110: 99,
#  111: 99,
#  112: 99,
#  113: 99,
#  114: 99,
#  115: 99,
#  116: 99,
#  117: 99,
#  118: 99,
#  119: 99,
#  120: 99,
#  121: 99,
#  122: 99,
#  123: 99,
#  124: 99,
#  125: 99,
#  126: 99,
#  127: 99,
#  128: 99,
#  129: 99,
#  130: 99,
#  131: 99,
#  132: 99,
#  133: 99,
#  134: 99,
#  135: 99,
#  136: 99,
#  137: 99,
#  138: 99,
#  139: 99,
#  140: 99,
#  141: 99,
#  142: 99,
#  143: 99,
#  144: 99,
#  145: 99,
#  146: 99,
#  147: 99,
#  148: 99,
#  149: 99,
#  150: 99,
#  151: 99,
#  152: 99,
#  153: 99,
#  154: 99,
#  155: 99,
#  156: 99,
#  157: 99,
#  158: 99,
#  159: 99,
#  160: 99,
#  161: 99,
#  162: 99,
#  163: 99,
#  164: 99,
#  165: 99,
#  166: 99,
#  167: 99,
#  168: 99,
#  169: 99,
#  170: 99,
#  171: 99,
#  172: 99,
#  173: 99,
#  174: 99,
#  175: 99,
#  176: 99,
#  177: 99,
#  178: 99,
#  179: 99,
#  180: 99,
#  181: 99,
#  182: 99,
#  183: 99,
#  184: 99,
#  185: 99,
#  186: 99,
#  187: 99,
#  188: 99,
#  189: 99,
#  190: 99,
#  191: 99,
#  192: 99,
#  193: 99,
#  194: 99,
#  195: 99,
#  196: 99,
#  197: 99,
#  198: 99,
#  199: 99,
#  200: 99,
#  201: 99,
#  202: 99,
#  203: 99,
#  204: 99,
#  205: 99,
#  206: 99,
#  207: 99,
#  208: 99,
#  209: 99,
#  210: 99,
#  211: 99,
#  212: 99,
#  213: 99,
#  214: 99,
#  215: 99,
#  216: 99,
#  217: 99,
#  218: 99,
#  219: 99,
#  220: 99,
#  221: 99,
#  222: 99,
#  223: 99,
#  224: 99,
#  225: 99,
#  226: 99,
#  227: 99,
#  228: 99,
#  229: 99,
#  230: 99,
#  231: 99,
#  232: 99,
#  233: 99,
#  234: 99,
#  235: 99,
#  236: 99,
#  237: 99,
#  238: 99,
#  239: 99,
#  240: 99,
#  241: 99,
#  242: 99,
#  243: 99,
#  244: 99,
#  245: 99,
#  246: 99,
#  247: 99,
#  248: 99,
#  249: 99,
#  250: 99,
#  251: 99,
#  252: 99,
#  253: 99,
#  254: 99,
#  255: 99,
#  256: 99,
#  257: 99,
#  258: 99,
#  259: 99,
#  260: 99,
#  261: 99,
#  262: 99,
#  263: 99,
#  264: 99,
#  265: 99,
#  266: 99,
#  267: 99,
#  268: 99,
#  269: 99,
#  270: 99,
#  271: 99,
#  272: 99,
#  273: 99,
#  274: 99,
#  275: 99,
#  276: 99,
#  277: 99,
#  278: 99,
#  279: 99,
#  280: 99,
#  281: 99,
#  282: 99,
#  283: 99,
#  284: 99,
#  285: 99,
#  286: 99,
#  287: 99,
#  288: 99,
#  289: 99,
#  290: 99,
#  291: 99,
#  292: 99,
#  293: 99,
#  294: 99,
#  295: 99,
#  296: 99,
#  297: 99,
#  298: 99,
#  299: 99,
#  300: 99,
#  301: 99,
#  302: 99,
#  303: 99,
#  304: 99,
#  305: 99,
#  306: 99,
#  307: 99,
#  308: 99,
#  309: 99,
#  310: 99,
#  311: 99,
#  312: 99,
#  313: 99,
#  314: 99,
#  315: 99,
#  316: 99,
#  317: 99,
#  318: 99,
#  319: 99,
#  320: 99,
#  321: 99,
#  322: 99,
#  323: 99,
#  324: 99,
#  325: 99,
#  326: 99,
#  327: 99,
#  328: 99,
#  329: 99,
#  330: 99,
#  331: 99,
#  332: 99,
#  333: 99,
#  334: 99,
#  335: 99,
#  336: 99,
#  337: 99,
#  338: 99,
#  339: 99,
#  340: 99,
#  341: 99,
#  342: 99,
#  343: 99,
#  344: 99,
#  345: 99,
#  346: 99,
#  347: 99,
#  348: 99,
#  349: 99,
#  350: 99,
#  351: 99,
#  352: 99,
#  353: 99,
#  354: 99,
#  355: 99,
#  356: 99,
#  357: 99,
#  358: 99,
#  359: 99,
#  360: 99,
#  361: 99,
#  362: 99,
#  363: 99,
#  364: 99,
#  365: 99,
#  366: 99,
#  367: 99,
#  368: 99,
#  369: 99,
#  370: 99,
#  371: 99,
#  372: 99,
#  373: 99,
#  374: 99,
#  375: 99,
#  376: 99,
#  377: 99,
#  378: 99,
#  379: 99,
#  380: 99,
#  381: 99,
#  382: 99,
#  383: 99,
#  384: 99,
#  385: 99,
#  386: 99,
#  387: 99,
#  388: 99,
#  389: 99,
#  390: 99,
#  391: 99,
#  392: 99,
#  393: 99,
#  394: 99,
#  395: 99,
#  396: 99,
#  397: 99,
#  398: 99,
#  399: 99,
#  400: 99,
#  401: 99,
#  402: 99,
#  403: 99,
#  404: 99,
#  405: 99,
#  406: 99,
#  407: 99,
#  408: 99,
#  409: 99,
#  410: 99,
#  411: 99,
#  412: 99,
#  413: 99,
#  414: 99,
#  415: 99,
#  416: 99,
#  417: 99,
#  418: 99,
#  419: 99,
#  420: 99,
#  421: 99,
#  422: 99,
#  423: 99,
#  424: 99,
#  425: 99,
#  426: 99,
#  427: 99,
#  428: 99,
#  429: 99,
#  430: 99,
#  431: 99,
#  432: 99,
#  433: 99,
#  434: 99,
#  435: 99,
#  436: 99,
#  437: 99,
#  438: 99,
#  439: 99,
#  440: 99,
#  441: 99,
#  442: 99,
#  443: 99,
#  444: 99,
#  445: 99,
#  446: 99,
#  447: 99,
#  448: 99,
#  449: 99,
#  450: 99,
#  451: 99,
#  452: 99,
#  453: 99,
#  454: 99,
#  455: 99,
#  456: 99,
#  457: 99,
#  458: 99,
#  459: 99,
#  460: 99,
#  461: 99,
#  462: 99,
#  463: 99,
#  464: 99,
#  465: 99,
#  466: 99,
#  467: 99,
#  468: 99,
#  469: 99,
#  470: 99,
#  471: 99,
#  472: 99,
#  473: 99,
#  474: 99,
#  475: 99,
#  476: 99,
#  477: 99,
#  478: 99,
#  479: 99,
#  480: 99,
#  481: 99,
#  482: 99,
#  483: 99,
#  484: 99,
#  485: 99,
#  486: 99,
#  487: 99,
#  488: 99,
#  489: 99,
#  490: 99,
#  491: 99,
#  492: 99,
#  493: 99,
#  494: 99,
#  495: 99,
#  496: 99,
#  497: 99,
#  498: 99,
#  499: 99,
#  500: 99,
#  501: 99,
#  502: 99,
#  503: 99,
#  504: 99,
#  505: 99,
#  506: 99,
#  507: 99,
#  508: 99,
#  509: 99,
#  510: 99,
#  511: 99,
#  512: 99,
#  513: 99,
#  514: 99,
#  515: 99,
#  516: 99,
#  517: 99,
#  518: 99,
#  519: 99,
#  520: 99,
#  521: 99,
#  522: 99,
#  523: 99,
#  524: 99,
#  525: 99,
#  526: 99,
#  527: 99,
#  528: 99,
#  529: 99,
#  530: 99,
#  531: 99,
#  532: 99,
#  533: 99,
#  534: 99,
#  535: 99,
#  536: 0,
#  537: 0,
#  538: 0,
#  539: 0,
#  540: 0,
#  541: 0,
#  542: 0,
#  543: 0,
#  544: 0,
#  545: 0,
#  546: 0,
#  547: 0,
#  548: 0,
#  549: 0,
#  550: 0,
#  551: 0,
#  552: 0,
#  553: 0,
#  554: 0,
#  555: 0,
#  556: 0,
#  557: 0,
#  558: 0,
#  559: 0,
#  560: 0,
#  561: 0,
#  562: 0,
#  563: 0,
#  564: 0,
#  565: 0,
#  566: 0,
#  567: 0,
#  568: 0,
#  569: 0,
#  570: 0,
#  571: 0,
#  572: 0,
#  573: 0,
#  574: 0,
#  575: 0,
#  576: 0,
#  577: 0,
#  578: 0,
#  579: 0,
#  580: 0,
#  581: 0,
#  582: 0,
#  583: 0,
#  584: 0,
#  585: 0,
#  586: 1,
#  587: 1,
#  588: 1,
#  589: 1,
#  590: 1,
#  591: 1,
#  592: 1,
#  593: 1,
#  594: 1,
#  595: 1,
#  596: 1,
#  597: 1,
#  598: 1,
#  599: 1,
#  600: 1,
#  601: 1,
#  602: 1,
#  603: 1,
#  604: 1,
#  605: 1,
#  606: 1,
#  607: 1,
#  608: 1,
#  609: 1,
#  610: 1,
#  611: 1,
#  612: 1,
#  613: 1,
#  614: 1,
#  615: 1,
#  616: 1,
#  617: 1,
#  618: 1,
#  619: 1,
#  620: 1,
#  621: 1,
#  622: 1,
#  623: 1,
#  624: 1,
#  625: 1,
#  626: 1,
#  627: 1,
#  628: 1,
#  629: 1,
#  630: 1,
#  631: 1,
#  632: 1,
#  633: 1,
#  634: 1,
#  635: 1,
#  636: 2,
#  637: 2,
#  638: 2,
#  639: 2,
#  640: 2,
#  641: 2,
#  642: 2,
#  643: 2,
#  644: 2,
#  645: 2,
#  646: 2,
#  647: 2,
#  648: 2,
#  649: 2,
#  650: 2,
#  651: 2,
#  652: 2,
#  653: 2,
#  654: 2,
#  655: 2,
#  656: 2,
#  657: 2,
#  658: 2,
#  659: 2,
#  660: 2,
#  661: 2,
#  662: 2,
#  663: 2,
#  664: 2,
#  665: 2,
#  666: 2,
#  667: 2,
#  668: 2,
#  669: 2,
#  670: 2,
#  671: 2,
#  672: 2,
#  673: 2,
#  674: 2,
#  675: 2,
#  676: 2,
#  677: 2,
#  678: 2,
#  679: 2,
#  680: 2,
#  681: 2,
#  682: 2,
#  683: 2,
#  684: 2,
#  685: 2,
#  686: 4,
#  687: 4,
#  688: 4,
#  689: 4,
#  690: 4,
#  691: 4,
#  692: 4,
#  693: 4,
#  694: 4,
#  695: 4,
#  696: 4,
#  697: 4,
#  698: 4,
#  699: 4,
#  700: 4,
#  701: 4,
#  702: 4,
#  703: 4,
#  704: 4,
#  705: 4,
#  706: 4,
#  707: 4,
#  708: 4,
#  709: 4,
#  710: 4,
#  711: 4,
#  712: 4,
#  713: 4,
#  714: 4,
#  715: 4,
#  716: 4,
#  717: 4,
#  718: 4,
#  719: 4,
#  720: 4,
#  721: 4,
#  722: 1,
#  723: 4,
#  724: 4,
#  725: 4,
#  726: 4,
#  727: 4,
#  728: 4,
#  729: 4,
#  730: 4,
#  731: 4,
#  732: 4,
#  733: 4,
#  734: 4,
#  735: 4,
#  736: 5,
#  737: 5,
#  738: 5,
#  739: 5,
#  740: 5,
#  741: 5,
#  742: 5,
#  743: 5,
#  744: 5,
#  745: 5,
#  746: 5,
#  747: 5,
#  748: 5,
#  749: 5,
#  750: 5,
#  751: 5,
#  752: 5,
#  753: 5,
#  754: 5,
#  755: 5,
#  756: 5,
#  757: 5,
#  758: 5,
#  759: 5,
#  760: 5,
#  761: 5,
#  762: 5,
#  763: 5,
#  764: 5,
#  765: 5,
#  766: 5,
#  767: 5,
#  768: 5,
#  769: 5,
#  770: 5,
#  771: 5,
#  772: 5,
#  773: 5,
#  774: 5,
#  775: 5,
#  776: 5,
#  777: 5,
#  778: 5,
#  779: 5,
#  780: 5,
#  781: 5,
#  782: 5,
#  783: 5,
#  784: 5,
#  785: 5,
#  786: -1,
#  787: -1,
#  788: -1,
#  789: -1,
#  790: -1,
#  791: -1,
#  792: -1,
#  793: -1,
#  794: -1,
#  795: -1,
#  796: -1,
#  797: -1,
#  798: -1,
#  799: -1,
#  800: -1,
#  801: -1,
#  802: -1,
#  803: -1,
#  804: -1,
#  805: -1,
#  806: -1,
#  807: -1,
#  808: -1,
#  809: -1,
#  810: -1,
#  811: -1,
#  812: -1,
#  813: -1,
#  814: -1,
#  815: -1,
#  816: -1,
#  817: -1,
#  818: -1,
#  819: -1,
#  820: -1,
#  821: -1,
#  822: -1,
#  823: -1,
#  824: -1,
#  825: -1,
#  826: -1,
#  827: -1,
#  828: -1,
#  829: -1,
#  830: -1,
#  831: -1,
#  832: -1,
#  833: -1,
#  834: -1,
#  835: -1}

# %%
# GCN 分类结果
gcn_pred_path = os.path.join(path,graph_type,'pred_labels_all.txt')
nodeid2gcnpred = dict()
with open(gcn_pred_path,'r',encoding='utf-8') as fr_pred_labels_all:
    lines = fr_pred_labels_all.readlines()
    num_lines = len(lines)
    for i in range(num_lines):
        pred,label = lines[i].strip('\n').split('\t')
        nodeid2gcnpred[i] = int(pred)
# nodeid2gcnpred

# %% [markdown]
# Configuring the experiment you want to visualize. These values should match the configuration:
#
# > TODO: Unify configuration of experiments in yaml

# %%
label_iidx = '2投诉曝光'
method = 'att'
logdir = r"E:\0_code\gnn-model-explainer-master_hql"
logdir = os.path.join(logdir,'log\\npy',method,graph_type,str(label_iidx))
expdir = ''
logdir
# Out:
# 'E:\\0_code\\gnn-model-explainer-master_hql\\log\\npy\\att\\doc_word_sen\\2投诉曝光'

# %%
# Load the produced masks

# %%
dirs = os.listdir(os.path.join(logdir))
dirs
# Out:
# ['masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_636graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_637graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_639graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_640graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_642graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_643graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_644graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_645graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_647graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_648graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_649graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_650graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_651graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_654graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_655graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_656graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_657graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_658graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_659graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_661graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_663graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_665graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_667graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_668graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_669graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_671graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_673graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_674graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_676graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_678graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_679graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_680graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_683graph_idx_-1.npy',
#  'masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_684graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_636graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_637graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_639graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_640graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_642graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_643graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_644graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_645graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_647graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_648graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_649graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_650graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_651graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_654graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_655graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_656graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_657graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_658graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_659graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_661graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_663graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_665graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_667graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_668graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_669graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_671graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_673graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_674graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_676graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_678graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_679graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_680graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_683graph_idx_-1.npy',
#  'masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_684graph_idx_-1.npy']

# %%
masks = []
idx = []
neighbors = []
# This would print all the files and directories
for file in dirs:
    if file.split('.')[-1] == 'npy':
        print(file)
        idx.extend(re.findall(r"(\d+)graph",file.split('_')[-3]))
        name_list = file.split('_')
        if name_list[1] == 'adj':
            masks.append(file)
        elif name_list[1] == 'neighbors':
            neighbors.append(file)
# Out:
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_636graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_637graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_639graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_640graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_642graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_643graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_644graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_645graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_647graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_648graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_649graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_650graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_651graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_654graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_655graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_656graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_657graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_658graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_659graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_661graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_663graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_665graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_667graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_668graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_669graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_671graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_673graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_674graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_676graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_678graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_679graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_680graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_683graph_idx_-1.npy
# masked_adj_im_doc_word_sen_att_h512_o256_explainnode_idx_684graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_636graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_637graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_639graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_640graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_642graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_643graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_644graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_645graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_647graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_648graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_649graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_650graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_651graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_654graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_655graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_656graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_657graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_658graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_659graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_661graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_663graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_665graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_667graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_668graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_669graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_671graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_673graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_674graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_676graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_678graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_679graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_680graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_683graph_idx_-1.npy
# masked_neighbors_im_doc_word_sen_att_h512_o256_explainnode_idx_684graph_idx_-1.npy

# %%
import re
number = re.findall(r"(\d+)graph",masks[0].split('_')[-3]) #提取指定字符前的数字
number
# Out:
# ['536']

# %%
def get_node_color_by_gcn_pred(neighbors,nodeidx,nodes):
    ''' 根据节点GCN分类pred，给节点不同的颜色:nodeidx为红色，99-灰色，0-蓝色，1-黄色，2-绿色，4-橙色，'''
    color_map = {99:'thistle',0:'lightsteelblue',1:'gold',2:'yellowgreen',4:'lightsalmon',5:'violet',-1:'silver'}
    neighbors_ = np.load(os.path.join(logdir, expdir, neighbors), allow_pickle=True)
    neighbors_ = [neighbors_[node] for node in nodes] # 对应全局的idx
#     print(type(neighbors_[0]),type(nodeidx))
#     print(neighbors_,nodeidx,nodeidx in neighbors_)
    neighbors_gcnpred = [color_map[int(nodeid2gcnpred[nei])] for nei in neighbors_] #if int(nei)!= int(nodeidx) else 'red' 
    
    return neighbors_gcnpred

# %%
def get_neighbors_oriinfo(neighbors,nodes):
    ''' 获取neighbors 的中文  txt_wrap(nodeid2txt[str(nei)],7)'''
    neighbors_ = np.load(os.path.join(logdir, expdir, neighbors), allow_pickle=True)
    if len(neighbors_):
        neighbors_ = [neighbors_[node] for node in nodes]
        neighbors_txts_labels = [[nodeid2txt[str(nei)],label_map[int(nodeid2label[nei])],label_map_pred[int(nodeid2gcnpred[nei])]] for nei in neighbors_]
        return neighbors_txts_labels
    return []

# %%
def show_adjacency_full(mask, ax=None):
    adj = np.load(os.path.join(logdir, mask), allow_pickle=True)
    if ax is None:
        plt.figure()
        plt.imshow(adj);
    else:
        ax.imshow(adj)
    return adj

# %%
def filter_adj(adj):
    filt_adj = adj.copy()
    filt_adj[adj<0.8] = 0
    return filt_adj

# %%
for m,i,neibor in zip(masks,idx,neighbors): 

    fig, (ax1, ax2, ax3,ax4) = plt.subplots(1, 4, figsize=(20,5))
    plt.title(str(m))
    
    # Full adjacency
    ax1.set_title('Full Adjacency mask')
    adj = show_adjacency_full(m, ax=ax1)
    
    # Filtered adjacency
    f = filter_adj(adj)
    ax2.set_title('Full Adjacency mask of Subgraph')
    ax2.imshow(f);
    
    # Plot subgraph
    ax3.set_title(f"Subgraph of '{nodeid2txt[i]}'")
    G = nx.from_numpy_array(f)
    G.remove_nodes_from(list(nx.isolates(G)))
    node_colors = get_node_color_by_gcn_pred(neibor,i,G.nodes)
    nx.draw(G,pos=nx.circular_layout(G),with_labels=True,ax=ax3,node_color=node_colors)
    
    # Plot nodeidx2txt
    ax4.set_title(f"Mapping of nodeidx and text")
    neighbors_txts_labels = get_neighbors_oriinfo(neibor,G.nodes)
    if len(neighbors_txts_labels):
        tab = plt.table(cellText=neighbors_txts_labels, 
                      colLabels=['txt','label,'pred'], 
                     rowLabels=[str(n) for n in G.nodes],
                      loc='center', 
                      cellLoc='center',
                      rowLoc='center')
        tab.auto_set_font_size(True)
        tab.set_fontsize(16)
        tab.scale(1,2) 
    plt.axis('off')
    os.makedirs("E:\\0_code\\gnn-model-explainer-master_hql\\log\\subgraph\\att\\"+graph_type+'\\'+str(label_iidx), exist_ok=True)
#     plt.savefig("E:\\0_code\\gnn-model-explainer-master_hql\\log\\subgraph\\att\\"+graph_type+'\\'+str(label_iidx)+'\\' + m[:-4] + ".png")
# Out:
# d:\users\ql.hua\pycharmprojects\gnn-model-explainer-master\venv\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until
